# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv2
import tensorflow as tf
import os
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Bidirectional, LSTM, Dense, Dropout, Flatten, Embedding,Reshape,TimeDistributed
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models
from keras.utils import to_categorical
from keras import layers
import warnings

warnings.filterwarnings('ignore')
# Out:
# 2024-02-14 08:50:29.415706: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-14 08:50:29.415825: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-14 08:50:29.543690: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
! conda install -y gdown
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): | WARNING conda.models.version:get_matcher(556): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 24.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.1.1
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - gdown
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2024.2.2   |       hbcca054_0         152 KB  conda-forge
#     certifi-2024.2.2           |     pyhd8ed1ab_0         157 KB  conda-forge
#     filelock-3.13.1            |     pyhd8ed1ab_0          15 KB  conda-forge
#     gdown-5.1.0                |     pyhd8ed1ab_0          21 KB  conda-forge
#     openssl-3.2.1              |       hd590300_0         2.7 MB  conda-forge
#     scipy-1.12.0               |  py310hb13e2d6_2        15.7 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        18.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   filelock           conda-forge/noarch::filelock-3.13.1-pyhd8ed1ab_0
#   gdown              conda-forge/noarch::gdown-5.1.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.11.17-hbcca054_0 --> 2024.2.2-hbcca054_0
#   certifi                           2023.11.17-pyhd8ed1ab_0 --> 2024.2.2-pyhd8ed1ab_0
#   openssl                                  3.2.0-hd590300_1 --> 3.2.1-hd590300_0
#   scipy                              1.12.0-py310hb13e2d6_1 --> 1.12.0-py310hb13e2d6_2
#
#
#
# Downloading and Extracting Packages
# openssl-3.2.1        | 2.7 MB    |                                       |   0%
# ca-certificates-2024 | 152 KB    |                                       |   0%
#
# scipy-1.12.0         | 15.7 MB   |                                       |   0%
#
#
# filelock-3.13.1      | 15 KB     |                                       |   0%
#
#
#
# gdown-5.1.0          | 21 KB     |                                       |   0%
#
#
#
#
# openssl-3.2.1        | 2.7 MB    | 2                                     |   1%
# ca-certificates-2024 | 152 KB    | ###9                                  |  11%
#
# scipy-1.12.0         | 15.7 MB   |                                       |   0%
#
#
#
#
# certifi-2024.2.2     | 157 KB    | ###7                                  |  10%
#
#
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
#
#
# filelock-3.13.1      | 15 KB     | ##################################### | 100%
#
#
#
# gdown-5.1.0          | 21 KB     | ##################################### | 100%
#
#
#
# gdown-5.1.0          | 21 KB     | ##################################### | 100%
# openssl-3.2.1        | 2.7 MB    | ######################4               |  61%
#
#
#
#
# certifi-2024.2.2     | 157 KB    | ##################################### | 100%
#
# scipy-1.12.0         | 15.7 MB   | ##9                                   |   8%
#
# openssl-3.2.1        | 2.7 MB    | ##################################### | 100%
#
# scipy-1.12.0         | 15.7 MB   | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !gdown --id 1FD6lxf3yUFovc5b1vJVjER20wHY40FBH
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1FD6lxf3yUFovc5b1vJVjER20wHY40FBH
# To: /kaggle/working/integrate_2.csv
# 100%|███████████████████████████████████████| 11.4M/11.4M [00:00<00:00, 117MB/s]

# %%
df=pd.read_csv('/kaggle/working/integrate_2.csv')
label=df['Label']

# %%
df.shape
# Out:
# (998431, 2)

# %%
# !gdown --id 1rJoqICofnT9vI3a1-M0Jp0ivkMTahaTy
# Out:
# /opt/conda/lib/python3.10/site-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1rJoqICofnT9vI3a1-M0Jp0ivkMTahaTy
# From (redirected): https://drive.google.com/uc?id=1rJoqICofnT9vI3a1-M0Jp0ivkMTahaTy&confirm=t&uuid=c488202d-27b5-44e8-a04f-2c148eb17ad2
# To: /kaggle/working/New folder.zip
# 100%|█████████████████████████████████████████| 255M/255M [00:01<00:00, 226MB/s]

# %%
import zipfile
import io


with zipfile.ZipFile('/kaggle/working/New folder.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
images = []

for i in range(570749):
    img_dir = f'/kaggle/working/New folder/{i}.png'
    try:
        img = cv2.imread(img_dir, cv2.IMREAD_GRAYSCALE)  # Read image in grayscale

        height, original_width = img.shape
        if 25 - original_width > 0:
            add_width = (25 - original_width) / 2
            left_columns = int(add_width)
            right_columns = int(add_width)
            new_width = 25
            new_img = np.zeros((height, new_width), dtype=np.uint8)
            new_img[:, left_columns:left_columns + original_width] = img
            new_img = cv2.resize(new_img, (new_width, 30))
        else:
            new_img = cv2.resize(img, (25, 30))

        _, binary_image = cv2.threshold(new_img, 128, 255, cv2.THRESH_BINARY)
        images.append(binary_image)
    except Exception as e:
        print(f"Error processing image {i}.png:", str(e))

# %%
len(images)
# Out:
# 570749

# %%
len(df)
# Out:
# 998431

# %%
len(label)
# Out:
# 998431

# %%
i=570748
plt.imshow(cv2.cvtColor(images[i], cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
print(label[i])
# Out:
# ر

# %%
images = images[:570749]
label = label[:570749]

# %%
len(label)
# Out:
# 570749

# %%
label_map = {}
current_label = 0
numeric_labels = []

for char in label:
    if char not in label_map:
        # If not, assign a new label
        label_map[char] = current_label
        current_label += 1
    numeric_labels.append(label_map[char])

# %%
label_map
# Out:
# {'ر': 0,
#  'ا': 1,
#  'ﯾ': 2,
#  'ﻧ': 3,
#  'ﻪ': 4,
#  'ﻗ': 5,
#  'ﭘ': 6,
#  'ن': 7,
#  'د': 8,
#  'ﺗ': 9,
#  'پ': 10,
#  'ز': 11,
#  'ﻫ': 12,
#  'ل': 13,
#  'ﺳ': 14,
#  'و': 15,
#  'م': 16,
#  'ﺣ': 17,
#  'ﻣ': 18,
#  'ط': 19,
#  'آ': 20,
#  'ﭼ': 21,
#  'ﻓ': 22,
#  'ه': 23,
#  'ﺑ': 24,
#  'ی': 25,
#  'ﮐ': 26,
#  'ﻟ': 27,
#  'ژ': 28,
#  'ﺟ': 29,
#  'ﺧ': 30,
#  'ﻻ': 31,
#  'ﺻ': 32,
#  'ص': 33,
#  'ﺷ': 34,
#  'ت': 35,
#  'ﮔ': 36,
#  'ف': 37,
#  'ک': 38,
#  'ع': 39,
#  'ﻌ': 40,
#  'ﻬ': 41,
#  'ذ': 42,
#  'ح': 43,
#  'س': 44,
#  'گ': 45,
#  'خ': 46,
#  'ش': 47,
#  'ﺿ': 48,
#  'ﻋ': 49,
#  'ب': 50,
#  'ظ': 51,
#  'ﻏ': 52,
#  'ض': 53,
#  'ق': 54,
#  'ج': 55,
#  'چ': 56,
#  'ﺋ': 57,
#  'غ': 58,
#  'ث': 59,
#  'ﺛ': 60,
#  'ﻐ': 61,
#  'ﻳ': 62,
#  '7': 63,
#  '3': 64,
#  '2': 65,
#  '9': 66,
#  '8': 67,
#  '6': 68,
#  '5': 69,
#  '4': 70,
#  '1': 71,
#  '0': 72}

# %%
len(label_map)
# Out:
# 73

# %%
print(label[1523])
print(numeric_labels[1523])
# Out:
# د
# 8

# %%
one_hot_labels = to_categorical(numeric_labels)
print("Shape of One-Hot Encoded Labels:", one_hot_labels.shape)
# Out:
# Shape of One-Hot Encoded Labels: (570749, 73)

# %%
from sklearn.utils import shuffle

imgs, OHL = shuffle(images, one_hot_labels, random_state=42)

# %%
del images
del one_hot_labels

# %%
plt.imshow(imgs[15162])
print(np.argmax(OHL[15162]))
# Out:
# 50

# %%
len(label.unique())
# Out:
# 73

# %%
imgs=np.expand_dims(imgs,axis=-1)
imgs = np.array(imgs)
imgs = imgs / 255.0

# %%
X_train, X_test, y_train, y_test = train_test_split(imgs, OHL, test_size=0.2, random_state=42,shuffle=False)

# %%
del imgs
del OHL

# %%
def AlexNet(input_shape, num_classes):
    model = models.Sequential([
        layers.Conv2D(64, (3, 3), strides=(1, 1), activation='relu', input_shape=input_shape),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        layers.Conv2D(192, (3, 3), padding='same', activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        layers.Conv2D(384, (3, 3), padding='same', activation='relu'),
        layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        layers.MaxPooling2D(pool_size=(2, 2), strides=(2, 2)),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
input_shape = (30, 25, 1)
num_classes = len(label.unique())
NN = AlexNet(input_shape, num_classes)

# %%
NN.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
NN.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 23, 64)        640
#
#  max_pooling2d (MaxPooling2  (None, 14, 11, 64)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 11, 192)       110784
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 5, 192)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 5, 384)         663936
#
#  conv2d_3 (Conv2D)           (None, 7, 5, 256)         884992
#
#  conv2d_4 (Conv2D)           (None, 7, 5, 256)         590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 2, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 1536)              0
#
#  dense (Dense)               (None, 4096)              6295552
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 73)                299081
#
# =================================================================
# Total params: 25626377 (97.76 MB)
# Trainable params: 25626377 (97.76 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=4, restore_best_weights=True)
history = NN.fit(X_train, y_train, epochs=15, batch_size=32,
                         validation_data=(X_test, y_test), callbacks=[early_stopping])
# Out:
# Epoch 1/15
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1707901817.886343    5137 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 14269/14269 [==============================] - 153s 10ms/step - loss: 0.7809 - accuracy: 0.8772 - val_loss: 0.5388 - val_accuracy: 0.9080
# Epoch 2/15
# 14269/14269 [==============================] - 144s 10ms/step - loss: 1.0042 - accuracy: 0.9014 - val_loss: 0.5232 - val_accuracy: 0.9068
# Epoch 3/15
# 14269/14269 [==============================] - 143s 10ms/step - loss: 0.8634 - accuracy: 0.9018 - val_loss: 0.5327 - val_accuracy: 0.9056
# Epoch 4/15
# 14269/14269 [==============================] - 142s 10ms/step - loss: 0.6048 - accuracy: 0.8927 - val_loss: 0.5115 - val_accuracy: 0.9093
# Epoch 5/15
# 14269/14269 [==============================] - 146s 10ms/step - loss: 1.5159 - accuracy: 0.9031 - val_loss: 0.5927 - val_accuracy: 0.9088
# Epoch 6/15
# 14269/14269 [==============================] - 145s 10ms/step - loss: 1.1614 - accuracy: 0.7496 - val_loss: 0.6220 - val_accuracy: 0.8742
# Epoch 7/15
# 14269/14269 [==============================] - 142s 10ms/step - loss: 0.6339 - accuracy: 0.8837 - val_loss: 0.5283 - val_accuracy: 0.8984
# Epoch 8/15
# 14269/14269 [==============================] - 142s 10ms/step - loss: 0.5953 - accuracy: 0.8926 - val_loss: 0.5259 - val_accuracy: 0.8986

# %%
training_loss = history.history['loss']
validation_loss = history.history['val_loss']
training_accuracy = history.history['accuracy']
validation_accuracy = history.history['val_accuracy']

# Plotting the loss
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(training_loss, label='Training Loss')
plt.plot(validation_loss, label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plotting the accuracy
plt.subplot(1, 2, 2)
plt.plot(training_accuracy, label='Training Accuracy')
plt.plot(validation_accuracy, label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ****Test The Model****

# %%
predictions=NN.predict(X_test,32)
# Out:
# 3568/3568 [==============================] - 8s 2ms/step

# %%
print(np.argmax(predictions[48]))
print(np.argmax(y_test[48]))
# Out:
# 24
# 24

# %%
print(np.argmax(predictions[12]))
print(np.argmax(y_test[12]))
# Out:
# 40
# 40

# %%
NN.evaluate(X_test,y_test)
# Out:
# 3568/3568 [==============================] - 13s 4ms/step - loss: 0.5115 - accuracy: 0.9093
# [0.51154625415802, 0.9092947840690613]

# %%
# NN.save('ocr-NN',save_format='h5')
NN.save('AlexNet.h5')

# %%
from IPython.display import FileLink
FileLink(r'AlexNet.h5')
# Out:
# /kaggle/working/AlexNet.h5
